# %% [markdown]
# # Ziel: Überführung der DPH-Daten aus Excel in ein CSV-Format für den Import in GeODin

# %%
import pandas as pd
import os
from DPH_Excel_to_CSV import parse_excel, stack_columns, write_csv, vorschachtung

# %% [markdown]
# ## Erste Excel lesen

# %%
df = parse_excel('DPH_Excel/DPH-153.xlsx')
df
# Out:
#    Tiefe Schläge Tiefe.1 Schläge.1 Tiefe.2 Schläge.2
# 2    0.1     NaN     3.1         4     6.1       NaN
# 3    0.2     NaN     3.2         5     6.2       NaN
# 4    0.3     NaN     3.3         5     6.3       NaN
# 5    0.4     NaN     3.4         4     6.4       NaN
# 6    0.5     NaN     3.5         5     6.5       NaN
# 7    0.6     NaN     3.6         5     6.6       NaN
# 8    0.7     NaN     3.7         5     6.7       NaN
# 9    0.8     NaN     3.8         4     6.8       NaN
# 10   0.9     NaN     3.9         4     6.9       NaN
# 11     1     NaN       4         5       7       NaN
# 12   1.1     NaN     4.1         5     7.1       NaN
# 13   1.2     NaN     4.2         4     7.2       NaN
# 14   1.3       2     4.3         4     7.3       NaN
# 15   1.4       2     4.4         4     7.4       NaN
# 16   1.5       3     4.5         5     7.5       NaN
# 17   1.6       3     4.6         6     7.6       NaN
# 18   1.7       3     4.7         6     7.7       NaN
# 19   1.8       3     4.8         5     7.8       NaN
# 20   1.9       2     4.9         5     7.9       NaN
# 21     2       3       5         6       8       NaN
# 22   2.1       4     5.1         6     8.1       NaN
# 23   2.2       4     5.2         5     8.2       NaN
# 24   2.3       4     5.3         6     8.3       NaN
# 25   2.4       3     5.4         6     8.4       NaN
# 26   2.5       4     5.5         6     8.5       NaN
# 27   2.6       4     5.6         5     8.6       NaN
# 28   2.7       5     5.7         5     8.7       NaN
# 29   2.8       5     5.8         6     8.8       NaN
# 30   2.9       5     5.9         6     8.9       NaN
# 31     3       4       6         6       9       NaN

# %% [markdown]
# ## Für CSV-Export vorbereiten

# %% [markdown]
# -> Stapeln, sodass alle Tiefen und alle Schläge in je einer Spalte sind

# %%
df_stacked = stack_columns(df)

df_bis_6 = df_stacked[df_stacked['Tiefe'] <= 6]

df_vorschachtung = vorschachtung(df_bis_6)

df_vorschachtung.head(20)
# Out:
# Vorschachtung bis  2.0 m.
#     Tiefe  Schläge
# 0     0.1      NaN
# 1     0.2      NaN
# 2     0.3      NaN
# 3     0.4      NaN
# 4     0.5      NaN
# 5     0.6      NaN
# 6     0.7      NaN
# 7     0.8      NaN
# 8     0.9      NaN
# 9     1.0      NaN
# 10    1.1      NaN
# 11    1.2      NaN
# 12    1.3      NaN
# 13    1.4      NaN
# 14    1.5      NaN
# 15    1.6      NaN
# 16    1.7      NaN
# 17    1.8      NaN
# 18    1.9      NaN
# 19    2.0      0.0

# %% [markdown]
# ## Loop über alle Excels im Ordner

# %%
for file in os.listdir('DPH_Excel'):
    if file.endswith('.xlsx'):
        # aktuelle Datei
        print('----', file, '----')
        
        # Excel lesen
        df = parse_excel(f"DPH_Excel/{file}")
        
        # Stapeln
        df_stacked = stack_columns(df)
        
        # DPHs nur bis 6 Meter
        df_bis_6 = df_stacked[df_stacked['Tiefe'] <= 6]
        
        # Vorschachtung
        df_vorschachtung = vorschachtung(df_bis_6)
        
        # CSV exportieren
        filename = file.replace('xlsx', 'csv')
        path = f"DPH_CSV/{filename}"
        write_csv(df_vorschachtung, path)
        print(filename, 'gespeichert.')
# Out:
# ---- DPH-116.xlsx ----
# Vorschachtung bis  2.0 m.
# DPH-116.csv gespeichert.
# ---- DPH-117.xlsx ----
# Vorschachtung bis  2.0 m.
# DPH-117.csv gespeichert.
# ---- DPH-118.xlsx ----
# DPH-118.csv gespeichert.
# ---- DPH-119.xlsx ----
# DPH-119.csv gespeichert.
# ---- DPH-122.xlsx ----
# DPH-122.csv gespeichert.
# ---- DPH-123.xlsx ----
# DPH-123.csv gespeichert.
# ---- DPH-124.xlsx ----
# DPH-124.csv gespeichert.
# ---- DPH-125.xlsx ----
# DPH-125.csv gespeichert.
# ---- DPH-126.xlsx ----
# DPH-126.csv gespeichert.
# ---- DPH-127.xlsx ----
# DPH-127.csv gespeichert.
# ---- DPH-132.xlsx ----
# DPH-132.csv gespeichert.
# ---- DPH-133.xlsx ----
# DPH-133.csv gespeichert.
# ---- DPH-140.xlsx ----
# DPH-140.csv gespeichert.
# ---- DPH-145.xlsx ----
# DPH-145.csv gespeichert.
# ---- DPH-147.xlsx ----
# DPH-147.csv gespeichert.
# ---- DPH-149.xlsx ----
# DPH-149.csv gespeichert.
# ---- DPH-150.xlsx ----
# Vorschachtung bis  1.2 m.
# DPH-150.csv gespeichert.
# ---- DPH-151.xlsx ----
# Vorschachtung bis  1.2 m.
# DPH-151.csv gespeichert.
# ---- DPH-152.xlsx ----
# Vorschachtung bis  1.2 m.
# DPH-152.csv gespeichert.
# ---- DPH-153.xlsx ----
# Vorschachtung bis  1.2 m.
# DPH-153.csv gespeichert.
# ---- DPH-154.xlsx ----
# DPH-154.csv gespeichert.
# ---- DPH-155.xlsx ----
# Vorschachtung bis  1.2 m.
# DPH-155.csv gespeichert.
# ---- DPH-156.xlsx ----
# DPH-156.csv gespeichert.
# ---- DPH-157.xlsx ----
# DPH-157.csv gespeichert.
# ---- DPH-161.xlsx ----
# DPH-161.csv gespeichert.
# ---- DPH-162.xlsx ----
# DPH-162.csv gespeichert.
# ---- DPH-163.xlsx ----
# DPH-163.csv gespeichert.
# ---- DPH-164.xlsx ----
# DPH-164.csv gespeichert.
# ---- DPH-165.xlsx ----
# DPH-165.csv gespeichert.
# ---- DPH-166.xlsx ----
# DPH-166.csv gespeichert.
# ---- DPH-167.xlsx ----
# DPH-167.csv gespeichert.
# ---- DPH-168.xlsx ----
# DPH-168.csv gespeichert.
# ---- DPH-169.xlsx ----
# DPH-169.csv gespeichert.
# ---- DPH-170.xlsx ----
# DPH-170.csv gespeichert.
# ---- DPH-171.xlsx ----
# DPH-171.csv gespeichert.
# ---- DPH-172.xlsx ----
# DPH-172.csv gespeichert.
# ---- DPH-173.xlsx ----
# DPH-173.csv gespeichert.
# ---- DPH-175.xlsx ----
# DPH-175.csv gespeichert.
# ---- DPH-176.xlsx ----
# DPH-176.csv gespeichert.
# ---- DPH-177.xlsx ----
# DPH-177.csv gespeichert.
# ---- DPH-178.xlsx ----
# DPH-178.csv gespeichert.
# ---- DPH-179.xlsx ----
# Vorschachtung bis  1.2 m.
# DPH-179.csv gespeichert.
# ---- DPH-180.xlsx ----
# DPH-180.csv gespeichert.
# ---- DPH-181.xlsx ----
# DPH-181.csv gespeichert.
# ---- DPH-183.xlsx ----
# DPH-183.csv gespeichert.
# ---- DPH-184.xlsx ----
# DPH-184.csv gespeichert.
# ---- DPH-185.xlsx ----
# DPH-185.csv gespeichert.
# ---- DPH-186.xlsx ----
# DPH-186.csv gespeichert.
# ---- DPH-187.xlsx ----
# DPH-187.csv gespeichert.
# ---- DPH-188.xlsx ----
# DPH-188.csv gespeichert.
# ---- DPH-189.xlsx ----
# DPH-189.csv gespeichert.
# ---- DPH-190.xlsx ----
# Vorschachtung bis  1.2 m.
# DPH-190.csv gespeichert.
# ---- DPH-191.xlsx ----
# DPH-191.csv gespeichert.
# ---- DPH-192.xlsx ----
# DPH-192.csv gespeichert.
# ---- DPH-193.xlsx ----
# DPH-193.csv gespeichert.
# ---- DPH-194.xlsx ----
# DPH-194.csv gespeichert.
# ---- DPH-195.xlsx ----
# Vorschachtung bis  1.2 m.
# DPH-195.csv gespeichert.
# ---- DPH-196.xlsx ----
# DPH-196.csv gespeichert.
# ---- DPH-197.xlsx ----
# DPH-197.csv gespeichert.
# ---- DPH-198.xlsx ----
# DPH-198.csv gespeichert.
# ---- DPH-199.xlsx ----
# DPH-199.csv gespeichert.
# ---- DPH-200.xlsx ----
# DPH-200.csv gespeichert.
# ---- DPH-201.xlsx ----
# DPH-201.csv gespeichert.
# ---- DPH-202.xlsx ----
# DPH-202.csv gespeichert.
# ---- DPH-217.xlsx ----
# DPH-217.csv gespeichert.
# ---- DPH-218.xlsx ----
# DPH-218.csv gespeichert.
# ---- DPH-219.xlsx ----
# DPH-219.csv gespeichert.
# ---- DPH-220.xlsx ----
# Vorschachtung bis  2.0 m.
# DPH-220.csv gespeichert.
# ---- DPH-221.xlsx ----
# DPH-221.csv gespeichert.
# ---- DPH-222.xlsx ----
# DPH-222.csv gespeichert.
# ---- DPH-224.xlsx ----
# DPH-224.csv gespeichert.
# ---- DPH-225.xlsx ----
# DPH-225.csv gespeichert.
# ---- DPH-226.xlsx ----
# DPH-226.csv gespeichert.
# ---- DPH-227.xlsx ----
# DPH-227.csv gespeichert.
# ---- DPH-228.xlsx ----
# DPH-228.csv gespeichert.
# ---- DPH-229.xlsx ----
# DPH-229.csv gespeichert.
# ---- DPH-230.xlsx ----
# DPH-230.csv gespeichert.
# ---- DPH-231.xlsx ----
# DPH-231.csv gespeichert.
# ---- DPH-M143.xlsx ----
# DPH-M143.csv gespeichert.
# ---- DPH-M146.xlsx ----
# DPH-M146.csv gespeichert.
# ---- DPH-M205.xlsx ----
# DPH-M205.csv gespeichert.
# ---- DPH-M206.xlsx ----
# DPH-M206.csv gespeichert.
# ---- DPH-M207.xlsx ----
# DPH-M207.csv gespeichert.
# ---- DPH-M209.xlsx ----
# DPH-M209.csv gespeichert.
# ---- DPH-M210.xlsx ----
# DPH-M210.csv gespeichert.
# ---- DPH-M211.xlsx ----
# DPH-M211.csv gespeichert.
# ---- DPH-M238.xlsx ----
# Vorschachtung bis  1.2 m.
# DPH-M238.csv gespeichert.
# ---- DPH-M239.xlsx ----
# Vorschachtung bis  1.2 m.
# DPH-M239.csv gespeichert.
# ---- DPH-M240.xlsx ----
# Vorschachtung bis  2.0 m.
# DPH-M240.csv gespeichert.
# ---- DPH-M360.xlsx ----
# DPH-M360.csv gespeichert.
# ---- DPH-M362.xlsx ----
# DPH-M362.csv gespeichert.
# ---- DPH-M362a.xlsx ----
# DPH-M362a.csv gespeichert.
# ---- DPH-M363.xlsx ----
# DPH-M363.csv gespeichert.
# ---- DPH-M364.xlsx ----
# DPH-M364.csv gespeichert.
# ---- DPH-M366.xlsx ----
# DPH-M366.csv gespeichert.
# ---- DPH-M366a.xlsx ----
# DPH-M366a.csv gespeichert.
# ---- DPH-M367.xlsx ----
# DPH-M367.csv gespeichert.
# ---- DPH-M369.xlsx ----
# DPH-M369.csv gespeichert.

# %% [markdown]
# ## Debug: Zählen, wie viele DPHs bis 6 Meter gehen

# %%
count = 0

for file in os.listdir('DPH_Excel'):
    if file.endswith('.xlsx'):
        df = parse_excel(f"DPH_Excel/{file}")
        df_stacked = stack_columns(df)

        if not pd.isnull(df_stacked.loc[6.0, 'Schläge']):
            count += 1
        else:
            print(file)
print(count)
# Out:
# DPH-125.xlsx
# 97

# %% [markdown]
# ## Testen der Funktionen

# %%
file = 'DPH-116.xlsx'

df = parse_excel(f"DPH_Excel/{file}")
df_stacked = stack_columns(df)
df_bis_6 = df_stacked[df_stacked['Tiefe'] <= 6]
df_vorschachtung = vorschachtung(df_bis_6)
filename = file.replace('xlsx', 'csv')
path = f"DPH_CSV/{filename}"
write_csv(df_vorschachtung, path)
# Out:
# Vorschachtung bis  2.0 m.
